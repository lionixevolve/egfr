# %%
using DataFrames
using Chemfiles
using Gadfly
using HypothesisTests
set_default_plot_size(40cm, 14cm)

home = "/home/german/labo/18/egfr/renonmis_gram/"
home_modos = "/home/german/labo/18/egfr/modos/"
home_rtdos = "/home/german/labo/18/egfr/rtdos_log/"
aa = 277
# Out:
# 277

# %%
function tognm(vtor_anm)
    vtor_gnm = Array{Float64}(convert(Int64, length(vtor_anm)/3));
    vtor_anm =  vtor_anm.^2
    for i=1:convert(Int64, length(vtor_anm)/3)
        vtor_gnm[i] = sqrt(vtor_anm[i*3-2] + vtor_anm[i*3-1] + vtor_anm[i*3])
    end
    return vtor_gnm
end
# Out:
# tognm (generic function with 1 method)

# %%
function WeightedHist(in_vec::Array{Float64, 1}, in_bins, in_weight, density = false)
    # Safety check    
    if length(in_vec) != length(in_weight)
        println("Each element of the input vector needs one weight")
        return
    end
    
    # Prepare variables
    out_counts = Array{Float64}(length(in_bins)-1)
    
    # Get weighted histogram
    for i=1:length(in_bins)-1
        if i == 1
            # Include those that fall before the beggining of the bins
            temp_bool = (in_vec .>= in_bins[i]) .& (in_vec .< in_bins[i+1]) .| (in_vec .<= in_bins[i])
            out_counts[i] = sum(in_weight[temp_bool])
        elseif i == length(in_bins)-1
            # Include those that fall after the end of the bins
            temp_bool = (in_vec .>= in_bins[i]) .& (in_vec .< in_bins[i+1]) .| (in_vec .>= in_bins[end])
            out_counts[i] = sum(in_weight[temp_bool])
        else
            temp_bool = (in_vec .>= in_bins[i]) .& (in_vec .< in_bins[i+1])
            out_counts[i] = sum(in_weight[temp_bool])
        end
    end
    
    # Get bins middle points
    out_middle = (in_bins[1:end-1] + in_bins[2:end]) / 2
    
    # Turn counts into density
    if (density == true)
        out_counts = out_counts ./ sum(out_counts) 
    end
    return out_counts, out_middle
end
# Out:
# WeightedHist (generic function with 2 methods)

# %% [markdown]
# # SVD

# %%
# Leo nombres de structuras
tmp = readdlm(string(home, "pdbs.list"))
pdbs_list = convert(Array{String, 1}, reshape(tmp, length(tmp)));
aa = 277
aa_3 = aa * 3
aa_36 = aa_3 - 6
structs = length(pdbs_list)

# Leo activas e inactivas
tmp = readdlm(string(home, "am.list"))
am_list = convert(Array{String, 1}, reshape(tmp, length(tmp)));

tmp = readdlm(string(home, "im.list"))
im_list = convert(Array{String, 1}, reshape(tmp, length(tmp)));

# %%
# Leo todos los residuos de pocket
tmp = readdlm(string(home, "nonmis_aa_pocket"))
aa_pocket = convert(Array{Int64, 1}, reshape(tmp, length(tmp)))

aa_pocket_nonmis = length(aa_pocket)
aa_3_pocket_nonmis = aa_pocket_nonmis * 3

aa_pocket_3 = Array{Int64}(aa_3_pocket_nonmis)
for i = 1:aa_pocket_nonmis
    aa_pocket_3[3*i - 2] = aa_pocket[i] * 3 - 2
    aa_pocket_3[3*i - 1] = aa_pocket[i] * 3 - 1
    aa_pocket_3[3*i] = aa_pocket[i] * 3
end

# Leo modos modelo
modos_1m14 = readdlm(string(home_modos, "1M14_A/modos_1M14_A"))[:, 1:825]
modos_3w32 = readdlm(string(home_modos, "3W32_A/modos_3W32_A"))[:, 1:825];

# %% [markdown]
# ## Leo autovectores de los grammianos

# %%
# IM
ncombs_im =  length(im_list) * (length(im_list) - 1)
im_1 = Array{Float64, 2}(aa_36, ncombs_im)
im_2 = Array{Float64, 2}(aa_36, ncombs_im)
im_3 = Array{Float64, 2}(aa_36, ncombs_im)
im_4 = Array{Float64, 2}(aa_36, ncombs_im)
im_5 = Array{Float64, 2}(aa_36, ncombs_im)
k = 0

for each in im_list
    for cada in im_list
        if each == cada
           continue
        end
        k += 1
        tmp = readdlm(string(home, "eigenvectors/", each, "/uno_", each, "_", cada))
        im_1[:, k] = reshape(tmp, length(tmp))

        tmp = readdlm(string(home, "eigenvectors/", each, "/dos_", each, "_", cada))
        im_2[:, k] = reshape(tmp, length(tmp))

        tmp = readdlm(string(home, "eigenvectors/", each, "/tre_", each, "_", cada))
        im_3[:, k] = reshape(tmp, length(tmp))

        tmp = readdlm(string(home, "eigenvectors/", each, "/cua_", each, "_", cada))
        im_4[:, k] = reshape(tmp, length(tmp))

        tmp = readdlm(string(home, "eigenvectors/", each, "/cin_", each, "_", cada))
        im_5[:, k] = reshape(tmp, length(tmp))
    end
end

# %%
# AM
ncombs_am =  length(am_list) * (length(am_list) - 1)
am_1 = Array{Float64, 2}(aa_36, ncombs_am)
am_2 = Array{Float64, 2}(aa_36, ncombs_am)
am_3 = Array{Float64, 2}(aa_36, ncombs_am)
am_4 = Array{Float64, 2}(aa_36, ncombs_am)
am_5 = Array{Float64, 2}(aa_36, ncombs_am)
k = 0

for each in am_list
    for cada in am_list
        if each == cada
           continue 
        end
        k += 1
        tmp = readdlm(string(home, "eigenvectors/", each, "/uno_", each, "_", cada))
        am_1[:, k] = reshape(tmp, length(tmp))
        
        tmp = readdlm(string(home, "eigenvectors/", each, "/dos_", each, "_", cada))
        am_2[:, k] = reshape(tmp, length(tmp))
        
        tmp = readdlm(string(home, "eigenvectors/", each, "/tre_", each, "_", cada))
        am_3[:, k] = reshape(tmp, length(tmp))
        
        tmp = readdlm(string(home, "eigenvectors/", each, "/cua_", each, "_", cada))
        am_4[:, k] = reshape(tmp, length(tmp))
        
        tmp = readdlm(string(home, "eigenvectors/", each, "/cin_", each, "_", cada))
        am_5[:, k] = reshape(tmp, length(tmp))
    end
end

# %% [markdown]
# ## Obtengo  SVDs

# %%
# IM
u_im_1, s_im_1, v_im_1 = svd(im_1)
u_im_2, s_im_2, v_im_2 = svd(im_2)
u_im_3, s_im_3, v_im_3 = svd(im_3)
u_im_4, s_im_4, v_im_4 = svd(im_4)
u_im_5, s_im_5, v_im_5 = svd(im_5)

# AM
u_am_1, s_am_1, v_am_1 = svd(am_1)
u_am_2, s_am_2, v_am_2 = svd(am_2)
u_am_3, s_am_3, v_am_3 = svd(am_3)
u_am_4, s_am_4, v_am_4 = svd(am_4)
u_am_5, s_am_5, v_am_5 = svd(am_5);

# %% [markdown]
# ## Obtengo modos svd1/2/3/4/5 según struct modelo inactiva(3W32_A) y activa(1M14_A)

# %%
# IM
svd_im_1 = modos_3w32 * u_im_1[:, 1]
svd_im_2 = modos_3w32 * u_im_2[:, 1]
svd_im_3 = modos_3w32 * u_im_3[:, 1]
svd_im_4 = modos_3w32 * u_im_4[:, 1]
svd_im_5 = modos_3w32 * u_im_5[:, 1]

# AM
svd_am_1 = modos_1m14 * u_am_1[:, 1]
svd_am_2 = modos_1m14 * u_am_2[:, 1]
svd_am_3 = modos_1m14 * u_am_3[:, 1]
svd_am_4 = modos_1m14 * u_am_4[:, 1]
svd_am_5 = modos_1m14 * u_am_5[:, 1];

# %% [markdown]
# ## Leo modos 1, 2, 3, 4  y 5 de todas las structs

# %%
# IM
modos_im_1 = Array{Float64, 2}(aa_3, length(im_list))
modos_im_2 = Array{Float64, 2}(aa_3, length(im_list))
modos_im_3 = Array{Float64, 2}(aa_3, length(im_list))
modos_im_4 = Array{Float64, 2}(aa_3, length(im_list))
modos_im_5 = Array{Float64, 2}(aa_3, length(im_list))

k = 0
for each in im_list
    k += 1
    tmp = readdlm(string(home_modos, each, "/modos_", each));
    
    modos_im_1[:, k] = tmp[:, 1]
    modos_im_2[:, k] = tmp[:, 2]
    modos_im_3[:, k] = tmp[:, 3]
    modos_im_4[:, k] = tmp[:, 4]
    modos_im_5[:, k] = tmp[:, 5]
end

# AM
modos_am_1 = Array{Float64, 2}(aa_3, length(am_list))
modos_am_2 = Array{Float64, 2}(aa_3, length(am_list))
modos_am_3 = Array{Float64, 2}(aa_3, length(am_list))
modos_am_4 = Array{Float64, 2}(aa_3, length(am_list))
modos_am_5 = Array{Float64, 2}(aa_3, length(am_list))

k = 0
for each in am_list
    k += 1
    tmp = readdlm(string(home_modos, each, "/modos_", each));
    
    modos_am_1[:, k] = tmp[:, 1]
    modos_am_2[:, k] = tmp[:, 2]
    modos_am_3[:, k] = tmp[:, 3]
    modos_am_4[:, k] = tmp[:, 4]
    modos_am_5[:, k] = tmp[:, 5]
end

# %% [markdown]
# ## Obtengo pdtos escalares entre los modos SVD y los modos originales de las structs

# %%
# AM
dots_svd_am_1 = Array{Float64, 1}(length(am_list))
dots_svd_am_2 = Array{Float64, 1}(length(am_list))
dots_svd_am_3 = Array{Float64, 1}(length(am_list))
dots_svd_am_4 = Array{Float64, 1}(length(am_list))
dots_svd_am_5 = Array{Float64, 1}(length(am_list))

for i = 1:length(am_list)
dots_svd_am_1[i] = maximum(abs.( [ dot(svd_am_1, modos_am_1[:, i]) ; dot(svd_am_1, modos_am_2[:, i]) ;
    dot(svd_am_1, modos_am_3[:, i]) ; dot(svd_am_1, modos_am_4[:, i]) ; dot(svd_am_1, modos_am_5[:, i])] ))

dots_svd_am_2[i] = maximum(abs.( [ dot(svd_am_2, modos_am_1[:, i]) ; dot(svd_am_2, modos_am_2[:, i]) ;
    dot(svd_am_2, modos_am_3[:, i]) ; dot(svd_am_2, modos_am_4[:, i]) ; dot(svd_am_2, modos_am_5[:, i])] ))

dots_svd_am_3[i] = maximum(abs.( [ dot(svd_am_3, modos_am_1[:, i]) ; dot(svd_am_3, modos_am_2[:, i]) ;
    dot(svd_am_3, modos_am_3[:, i]) ; dot(svd_am_3, modos_am_4[:, i]) ; dot(svd_am_3, modos_am_5[:, i])] ))

dots_svd_am_4[i] = maximum(abs.( [ dot(svd_am_4, modos_am_1[:, i]) ; dot(svd_am_4, modos_am_2[:, i]) ;
    dot(svd_am_4, modos_am_3[:, i]) ; dot(svd_am_4, modos_am_4[:, i]) ; dot(svd_am_4, modos_am_5[:, i])] ))

dots_svd_am_5[i] = maximum(abs.( [ dot(svd_am_5, modos_am_1[:, i]) ; dot(svd_am_5, modos_am_2[:, i]) ;
    dot(svd_am_5, modos_am_3[:, i]) ; dot(svd_am_5, modos_am_4[:, i]) ; dot(svd_am_5, modos_am_5[:, i])] ))
end

# IM
dots_svd_im_1 = Array{Float64, 1}(length(im_list))
dots_svd_im_2 = Array{Float64, 1}(length(im_list))
dots_svd_im_3 = Array{Float64, 1}(length(im_list))
dots_svd_im_4 = Array{Float64, 1}(length(im_list))
dots_svd_im_5 = Array{Float64, 1}(length(im_list))

for i = 1:length(im_list)
dots_svd_im_1[i] = maximum(abs.( [ dot(svd_im_1, modos_im_1[:, i]) ; dot(svd_im_1, modos_im_2[:, i]) ;
    dot(svd_im_1, modos_im_3[:, i]) ; dot(svd_im_1, modos_im_4[:, i]) ; dot(svd_im_1, modos_im_5[:, i])] ))

dots_svd_im_2[i] = maximum(abs.( [ dot(svd_im_2, modos_im_1[:, i]) ; dot(svd_im_2, modos_im_2[:, i]) ;
    dot(svd_im_2, modos_im_3[:, i]) ; dot(svd_im_2, modos_im_4[:, i]) ; dot(svd_im_2, modos_im_5[:, i])] ))

dots_svd_im_3[i] = maximum(abs.( [ dot(svd_im_3, modos_im_1[:, i]) ; dot(svd_im_3, modos_im_2[:, i]) ;
    dot(svd_im_3, modos_im_3[:, i]) ; dot(svd_im_3, modos_im_4[:, i]) ; dot(svd_im_3, modos_im_5[:, i])] ))

dots_svd_im_4[i] = maximum(abs.( [ dot(svd_im_4, modos_im_1[:, i]) ; dot(svd_im_4, modos_im_2[:, i]) ;
    dot(svd_im_4, modos_im_3[:, i]) ; dot(svd_im_4, modos_im_4[:, i]) ; dot(svd_im_4, modos_im_5[:, i])] ))

dots_svd_im_5[i] = maximum(abs.( [ dot(svd_im_5, modos_im_1[:, i]) ; dot(svd_im_5, modos_im_2[:, i]) ;
    dot(svd_im_5, modos_im_3[:, i]) ; dot(svd_im_5, modos_im_4[:, i]) ; dot(svd_im_5, modos_im_5[:, i])] ))
end

dots_svd_im_1 = dots_svd_im_1.^2
dots_svd_im_2 = dots_svd_im_2.^2
dots_svd_im_3 = dots_svd_im_3.^2
dots_svd_im_4 = dots_svd_im_4.^2
dots_svd_im_5 = dots_svd_im_5.^2

dots_svd_am_1 = dots_svd_am_1.^2
dots_svd_am_2 = dots_svd_am_2.^2
dots_svd_am_3 = dots_svd_am_3.^2
dots_svd_am_4 = dots_svd_am_4.^2
dots_svd_am_5 = dots_svd_am_5.^2;

# %% [markdown]
# ## Grafico

# %%
# 1
hbins = collect(minimum(dots_svd_im_1):0.05:maximum(dots_svd_am_1))
hweights_im = repeat([1.0], inner = [length(dots_svd_im_1)])
hweights_am = repeat([1.0], inner = [length(dots_svd_am_1)])

counts_im, bins = WeightedHist(dots_svd_im_1, hbins, hweights_im, true)
counts_am, bins = WeightedHist(dots_svd_am_1, hbins, hweights_am, true)


df_dots_svd_1 = DataFrame(Probability = [counts_am ; counts_im],
    Overlap = [ bins ; bins ],
    Conformer = repeat(["AM" ; "IM"], inner = [ length(bins)]))

# 2
hbins = collect(minimum(dots_svd_im_2):0.05:maximum(dots_svd_am_2))
hweights_im = repeat([1.0], inner = [length(dots_svd_im_2)])
hweights_am = repeat([1.0], inner = [length(dots_svd_am_2)])

counts_im, bins = WeightedHist(dots_svd_im_2, hbins, hweights_im, true)
counts_am, bins = WeightedHist(dots_svd_am_2, hbins, hweights_am, true)


df_dots_svd_2 = DataFrame(Probability = [counts_am ; counts_im],
    Overlap = [ bins ; bins ],
    Conformer = repeat(["AM" ; "IM"], inner = [ length(bins)]))

# 3
hbins = collect(minimum(dots_svd_im_3):0.05:maximum(dots_svd_am_3))
hweights_im = repeat([1.0], inner = [length(dots_svd_im_3)])
hweights_am = repeat([1.0], inner = [length(dots_svd_am_3)])

counts_im, bins = WeightedHist(dots_svd_im_3, hbins, hweights_im, true)
counts_am, bins = WeightedHist(dots_svd_am_3, hbins, hweights_am, true)


df_dots_svd_3 = DataFrame(Probability = [counts_am ; counts_im],
    Overlap = [ bins ; bins ],
    Conformer = repeat(["AM" ; "IM"], inner = [ length(bins)]))

# 4
hbins = collect(minimum(dots_svd_im_4):0.05:maximum(dots_svd_am_4))
hweights_im = repeat([1.0], inner = [length(dots_svd_im_4)])
hweights_am = repeat([1.0], inner = [length(dots_svd_am_4)])

counts_im, bins = WeightedHist(dots_svd_im_4, hbins, hweights_im, true)
counts_am, bins = WeightedHist(dots_svd_am_4, hbins, hweights_am, true)


df_dots_svd_4 = DataFrame(Probability = [counts_am ; counts_im],
    Overlap = [ bins ; bins ],
    Conformer = repeat(["AM" ; "IM"], inner = [ length(bins)]))

# 5
hbins = collect(minimum(dots_svd_im_5):0.05:maximum(dots_svd_am_5))
hweights_im = repeat([1.0], inner = [length(dots_svd_im_5)])
hweights_am = repeat([1.0], inner = [length(dots_svd_am_5)])

counts_im, bins = WeightedHist(dots_svd_im_5, hbins, hweights_im, true)
counts_am, bins = WeightedHist(dots_svd_am_5, hbins, hweights_am, true)


df_dots_svd_5 = DataFrame(Probability = [counts_am ; counts_im],
    Overlap = [ bins ; bins ],
    Conformer = repeat(["AM" ; "IM"], inner = [ length(bins)]));

# %%
pdf_dots_svd_1 = plot(df_dots_svd_1, x="Overlap", y="Probability", color = "Conformer", 
    Geom.bar(position = :dodge),

    #Guide.title("Figure 2.AA"),
    #Guide.ylabel("δV * Probability", orientation=:vertical), 
    #Guide.yticks(ticks = collect(0.25:0.25:1.0)),
    #Coord.cartesian(xmin = 0, xmax = 15),
    Scale.color_discrete_manual("Firebrick","SlateBlue"),


    Theme(bar_spacing = 2pt, grid_line_width=1pt, key_label_font_size = 20pt,
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %%
pdf_dots_svd_2 = plot(df_dots_svd_2, x="Overlap", y="Probability", color = "Conformer", 
    Geom.bar(position = :dodge),

    #Guide.title("Figure 2.AA"),
    #Guide.ylabel("δV * Probability", orientation=:vertical), 
    #Guide.yticks(ticks = collect(0.25:0.25:1.0)),
    #Coord.cartesian(xmin = 0, xmax = 15),
    Scale.color_discrete_manual("Firebrick","SlateBlue"),


    Theme(bar_spacing = 2pt, grid_line_width=1pt, key_label_font_size = 20pt,
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %%
pdf_dots_svd_3 = plot(df_dots_svd_3, x="Overlap", y="Probability", color = "Conformer", 
    Geom.bar(position = :dodge),

    #Guide.title("Figure 2.AA"),
    #Guide.ylabel("δV * Probability", orientation=:vertical), 
    #Guide.yticks(ticks = collect(0.25:0.25:1.0)),
    #Coord.cartesian(xmin = 0, xmax = 15),
    Scale.color_discrete_manual("Firebrick","SlateBlue"),


    Theme(bar_spacing = 2pt, grid_line_width=1pt, key_label_font_size = 20pt,
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %% [markdown]
# ## Guardo rtdos

# %% [markdown]
# # IM
# writedlm(string(home_rtdos, "dots_svd_im_1"), dots_svd_im_1)
# writedlm(string(home_rtdos, "dots_svd_im_1"), dots_svd_im_1)
# writedlm(string(home_rtdos, "dots_svd_im_2"), dots_svd_im_2)
# writedlm(string(home_rtdos, "dots_svd_im_3"), dots_svd_im_3)
# writedlm(string(home_rtdos, "dots_svd_im_4"), dots_svd_im_4)
# writedlm(string(home_rtdos, "dots_svd_im_5"), dots_svd_im_5)
#
# # AM
# writedlm(string(home_rtdos, "dots_svd_am_1"), dots_svd_am_1)
# writedlm(string(home_rtdos, "dots_svd_am_1"), dots_svd_am_1)
# writedlm(string(home_rtdos, "dots_svd_am_2"), dots_svd_am_2)
# writedlm(string(home_rtdos, "dots_svd_am_3"), dots_svd_am_3)
# writedlm(string(home_rtdos, "dots_svd_am_4"), dots_svd_am_4)
# writedlm(string(home_rtdos, "dots_svd_am_5"), dots_svd_am_5)

# %% [markdown]
# ### Guardo vectores obtenidos de los SVDs

# %% [markdown]
# # IM
# writedlm(string(home_rtdos, "svd_im_1"), svd_im_1)
# writedlm(string(home_rtdos, "svd_im_2"), svd_im_2)
#
# # AM
# writedlm(string(home_rtdos, "svd_am_1"), svd_am_1)
# writedlm(string(home_rtdos, "svd_am_2"), svd_am_2);

# %% [markdown]
# # Determino pnumbers de colectividad de modos 1 y 2

# %% [markdown]
# ### Reordeno modos antes de sacarles la colectividad

# %%
# IM
ref_im = 9
todos_im = [ modos_im_1 , modos_im_2 , modos_im_3 , modos_im_4 , modos_im_5 ]

# 1
new_modos_im_1 = Array{Float64, 2}(aa_3, length(im_list))
new_modos_im_1[:, ref_im] = modos_im_1[:, ref_im]
for i = 1:length(im_list)
    # Determino q modo de la struct actual tiene mayor solapimiento con el modo 1 de 3W32_A (referencia)
    tmp = abs.([ dot(modos_im_1[:, 9], modos_im_1[:, i]) ; dot(modos_im_1[:, ref_im], modos_im_2[:, i]) ;
        dot(modos_im_1[:, ref_im], modos_im_3[:, i]) ; dot(modos_im_1[:, ref_im], modos_im_4[:, i]) ; 
        dot(modos_im_1[:, ref_im], modos_im_5[:, i]) ])

    # Pongo ese modo como modo 1 de la struct actual
    new_modos_im_1[:, i] = todos_im[indmax(tmp)][:, i]
end

# 2
new_modos_im_2 = Array{Float64, 2}(aa_3, length(im_list))
new_modos_im_2[:, ref_im] = modos_im_2[:, ref_im]
for i = 1:length(im_list)
    # Determino q modo de la struct actual tiene mayor solapimiento con el modo 1 de 3W32_A (referencia)
    tmp = abs.([ dot(modos_im_2[:, 9], modos_im_1[:, i]) ; dot(modos_im_2[:, ref_im], modos_im_2[:, i]) ;
        dot(modos_im_2[:, ref_im], modos_im_3[:, i]) ; dot(modos_im_2[:, ref_im], modos_im_4[:, i]) ; 
        dot(modos_im_2[:, ref_im], modos_im_5[:, i]) ])

    # Pongo ese modo como modo 1 de la struct actual
    new_modos_im_2[:, i] = todos_im[indmax(tmp)][:, i]
end


# AM
ref_am = 1
todos_am = [ modos_am_1 , modos_am_2 , modos_am_3 , modos_am_4 , modos_am_5 ]

# 1
new_modos_am_1 = Array{Float64, 2}(aa_3, length(am_list))
new_modos_am_1[:, ref_am] = modos_am_1[:, ref_am]
for i = 2:length(am_list)
    # Determino q modo de la struct actual tiene mayor solapamiento con el modo 1 de 1M14_A (referencia)
    tmp = abs.([ dot(modos_am_1[:, ref_am], modos_am_1[:, i]) ; dot(modos_am_1[:, ref_am], modos_am_2[:, i]) ;
        dot(modos_am_1[:, ref_am], modos_am_3[:, i]) ; dot(modos_am_1[:, ref_am], modos_am_4[:, i]) ; 
        dot(modos_am_1[:, ref_am], modos_am_5[:, i]) ])

    # Pongo ese modo como modo 1 de la struct actual
    new_modos_am_1[:, i] = todos_am[indmax(tmp)][:, i]
end

# 2
new_modos_am_2 = Array{Float64, 2}(aa_3, length(am_list))
new_modos_am_2[:, ref_am] = modos_am_2[:, ref_am]
for i = 2:length(am_list)
    # Determino q modo de la struct actual tiene mayor solapamiento con el modo 1 de 1M14_A (referencia)
    tmp = abs.([ dot(modos_am_2[:, ref_am], modos_am_1[:, i]) ; dot(modos_am_2[:, ref_am], modos_am_2[:, i]) ;
        dot(modos_am_2[:, ref_am], modos_am_3[:, i]) ; dot(modos_am_2[:, ref_am], modos_am_4[:, i]) ; 
        dot(modos_am_2[:, ref_am], modos_am_5[:, i]) ])

    # Pongo ese modo como modo 1 de la struct actual
    new_modos_am_2[:, i] = todos_am[indmax(tmp)][:, i]
end

# %% [markdown]
# ### Obtengo pnumbers de colectividad

# %%
# IM
gnm_new_modos_im_1 = mapslices(x->tognm(x), new_modos_im_1, 1)
tmp = transpose((mapslices(x->sum(x), (gnm_new_modos_im_1 .^ 4), 1)) .^ -1) ./ aa
pnu_new_modos_im_1 = reshape(tmp, length(tmp))
# 2
gnm_new_modos_im_2 = mapslices(x->tognm(x), new_modos_im_2, 1)
tmp = transpose((mapslices(x->sum(x), (gnm_new_modos_im_2 .^ 4), 1)) .^ -1) ./ aa
pnu_new_modos_im_2 = reshape(tmp, length(tmp))

# AM
gnm_new_modos_am_1 = mapslices(x->tognm(x), new_modos_am_1, 1)
tmp = transpose((mapslices(x->sum(x), (gnm_new_modos_am_1 .^ 4), 1)) .^ -1) ./ aa
pnu_new_modos_am_1 = reshape(tmp, length(tmp))
# 2
gnm_new_modos_am_2 = mapslices(x->tognm(x), new_modos_am_2, 1)
tmp = transpose((mapslices(x->sum(x), (gnm_new_modos_am_2 .^ 4), 1)) .^ -1) ./ aa;
pnu_new_modos_am_2 = reshape(tmp, length(tmp));

# %% [markdown]
# ### Histogramas

# %%
# 1
hbins = collect(minimum(pnu_new_modos_im_1):0.02:maximum(pnu_new_modos_am_1))
hweights_im = repeat([1.0], inner = [length(pnu_new_modos_im_1)])
hweights_am = repeat([1.0], inner = [length(pnu_new_modos_am_1)])

counts_im, bins = WeightedHist(pnu_new_modos_im_1, hbins, hweights_im, true)
counts_am, bins = WeightedHist(pnu_new_modos_am_1, hbins, hweights_am, true)


df_hist_pnu_1 = DataFrame(Probability = [counts_im ; counts_am],
    Overlap = [ bins ; bins ],
    Conformer = repeat(["IM" ; "AM"], inner = [ length(bins)]));

# 1
hbins = collect(minimum(pnu_new_modos_im_2):0.02:maximum(pnu_new_modos_am_2))
hweights_im = repeat([1.0], inner = [length(pnu_new_modos_im_2)])
hweights_am = repeat([1.0], inner = [length(pnu_new_modos_am_2)])

counts_im, bins = WeightedHist(pnu_new_modos_im_2, hbins, hweights_im, true)
counts_am, bins = WeightedHist(pnu_new_modos_am_2, hbins, hweights_am, true)


df_hist_pnu_2 = DataFrame(Probability = [counts_im ; counts_am],
    Overlap = [ bins ; bins ],
    Conformer = repeat(["IM" ; "AM"], inner = [ length(bins)]));

# %% [markdown]
# ### Grafico

# %%
pdf_hist_pnu_1 = plot(df_hist_pnu_1, x="Overlap", y="Probability", color = "Conformer", 
    Geom.bar(position = :dodge),

    #Guide.title("Figure 2.AA"),
    #Guide.ylabel("δV * Probability", orientation=:vertical), 
    #Guide.yticks(ticks = collect(0.25:0.25:1.0)),
    #Coord.cartesian(xmin = 0, xmax = 15),
    Scale.color_discrete_manual("SlateBlue","Firebrick"),


    Theme(bar_spacing = 2pt, grid_line_width=1pt, key_label_font_size = 20pt,
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %%
pdf_hist_pnu_2 = plot(df_hist_pnu_2, x="Overlap", y="Probability", color = "Conformer", 
    Geom.bar(position = :dodge),

    #Guide.title("Figure 2.AA"),
    #Guide.ylabel("δV * Probability", orientation=:vertical), 
    #Guide.yticks(ticks = collect(0.25:0.25:1.0)),
    #Coord.cartesian(xmin = 0, xmax = 15),
    Scale.color_discrete_manual("SlateBlue","Firebrick"),


    Theme(bar_spacing = 2pt, grid_line_width=1pt, key_label_font_size = 20pt,
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %% [markdown]
# ## Stats de colectividades de pnum

# %% [markdown]
# ### IM

# %%
DataFrame(AVG = [ mean(pnu_new_modos_im_1) ; mean(pnu_new_modos_im_2) ], 
    SD = [ std(pnu_new_modos_im_1) ; std(pnu_new_modos_im_2) ])
# Out:
# 2×2 DataFrames.DataFrame
# │ Row │ AVG      │ SD        │
# ├─────┼──────────┼───────────┤
# │ 1   │ 0.104343 │ 0.0552926 │
# │ 2   │ 0.207772 │ 0.0996135 │

# %% [markdown]
# ### AM

# %%
DataFrame(AVG = [ mean(pnu_new_modos_am_1) ; mean(pnu_new_modos_am_2) ], 
    SD = [ std(pnu_new_modos_am_1) ; std(pnu_new_modos_am_2) ])
# Out:
# 2×2 DataFrames.DataFrame
# │ Row │ AVG      │ SD        │
# ├─────┼──────────┼───────────┤
# │ 1   │ 0.212946 │ 0.0345404 │
# │ 2   │ 0.172815 │ 0.0631772 │

# %%
ApproximateTwoSampleKSTest(pnu_new_modos_im_1, pnu_new_modos_am_1)
# Out:
# Approximate two sample Kolmogorov-Smirnov test
# ----------------------------------------------
# Population details:
#     parameter of interest:   Supremum of CDF differences
#     value under h_0:         0.0
#     point estimate:          0.828205128205128
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           4.303277484319119e-6
#
# Details:
#     number of observations:   [15,26]
#     KS-statistic:              2.554337565837795

# %%
ApproximateTwoSampleKSTest(pnu_new_modos_im_2, pnu_new_modos_am_2)
# Out:
# Approximate two sample Kolmogorov-Smirnov test
# ----------------------------------------------
# Population details:
#     parameter of interest:   Supremum of CDF differences
#     value under h_0:         0.0
#     point estimate:          0.35128205128205126
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.1910310809529836
#
# Details:
#     number of observations:   [15,26]
#     KS-statistic:              1.0834187198754737

# %% [markdown]
# ## Obtengo las proporciones de los SVDs en términos de los modos

# %%
# IM
tmp_im_1 = abs.(u_im_1[:, 1]) ./ sum(abs.(u_im_1[:, 1]))
tmp_im_2 = abs.(u_im_2[:, 1]) ./ sum(abs.(u_im_2[:, 1]))

# AM
tmp_am_1 = abs.(u_am_1[:, 1]) ./ sum(abs.(u_am_1[:, 1]))
tmp_am_2 = abs.(u_am_2[:, 1]) ./ sum(abs.(u_am_2[:, 1]));

# %%
DataFrame(SVD1_IM1 = [ tmp_im_1[1] ; tmp_im_1[2] ; tmp_im_1[3] ; tmp_im_1[4] ; tmp_im_1[5] ],
    SVD1_IM2 = [ tmp_im_2[1] ; tmp_im_2[2] ; tmp_im_2[3] ; tmp_im_2[4] ; tmp_im_2[5] ])
# Out:
# 5×2 DataFrames.DataFrame
# │ Row │ SVD1_IM1  │ SVD1_IM2   │
# ├─────┼───────────┼────────────┤
# │ 1   │ 0.760797  │ 0.703527   │
# │ 2   │ 0.0555495 │ 0.107659   │
# │ 3   │ 0.0123495 │ 0.00371129 │
# │ 4   │ 0.0339106 │ 0.0115714  │
# │ 5   │ 0.0153149 │ 0.0278373  │

# %%
DataFrame(SVD1_AM1 = [ tmp_am_1[1] ; tmp_am_1[2] ; tmp_am_1[3] ; tmp_am_1[4] ; tmp_am_1[5] ],
    SVD1_AM2 = [ tmp_am_2[1] ; tmp_am_2[2] ; tmp_am_2[3] ; tmp_am_2[4] ; tmp_am_2[5] ])
# Out:
# 5×2 DataFrames.DataFrame
# │ Row │ SVD1_AM1   │ SVD1_AM2   │
# ├─────┼────────────┼────────────┤
# │ 1   │ 0.943301   │ 0.0172768  │
# │ 2   │ 0.0167796  │ 0.884483   │
# │ 3   │ 0.00223296 │ 0.0249493  │
# │ 4   │ 0.0071953  │ 0.00556108 │
# │ 5   │ 0.00506321 │ 0.00725682 │

# %% [markdown]
# ### Guardo resultados

# %% [markdown]
# # IM
# writedlm(string(home_rtdos, "pnu_im_1"), pnu_new_modos_im_1)
# writedlm(string(home_rtdos, "pnu_im_2"), pnu_new_modos_im_2)
#
# # AM
# writedlm(string(home_rtdos, "pnu_am_1"), pnu_new_modos_am_1)
# writedlm(string(home_rtdos, "pnu_am_2"), pnu_new_modos_am_2);
